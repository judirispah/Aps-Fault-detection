# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata (18 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata (5.6 kB)
# ...
# Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
# Using cached numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...

# %%
import os
print(os.environ['CONDA_DEFAULT_ENV'])
# Out:
# lang

# %%
import os
print(os.environ['CONDA_DEFAULT_ENV'])

# %%
import  pandas as pd
data=pd.read_csv('aps_failure_training_set1.csv')

# %%
data.head()
# Out:
#   class  aa_000 ab_000 ac_000 ad_000 ae_000 af_000 ag_000  ag_001   ag_002  \
# 0   pos  153204      0    182     na      0      0      0       0        0
# 1   pos  453236     na   2926     na      0      0      0       0      222
# 2   pos   72504     na   1594   1052      0      0      0     244   178226
# 3   pos  762958     na     na     na     na     na    776  281128  2186308
# 4   pos  695994     na     na     na     na     na      0       0        0
#
#    ...   ee_002   ee_003   ee_004   ee_005   ee_006  ee_007  ee_008 ee_009  \
# 0  ...   129862    26872    34044    22472    34362       0       0      0
# 1  ...  7908038  3026002  5025350  2025766  1160638  533834  493800   6914
# 2  ...  1432098   372252   527514   358274   332818  284178    3742      0
# 3  ...       na       na       na       na       na      na      na     na
# 4  ...  1397742   495544   361646    28610     5130     212       0      0
#
#   ef_000 eg_000
# 0      0      0
# 1      0      0
# ...

# %%
json=data.to_dict(orient="records")

# %%
# !pip install pymongo
# Out:
# & was unexpected at this time.

# %%
import pymongo 
client=pymongo.MongoClient('mongodb+srv://judirispah:judirispah123@cluster0.cheikbw.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')

# %%
db_name="Aps_db"
collection_name="sensor_tb"

# %%
db=client[db_name]
collection=db[collection_name]

# %%
collection.insert_many(json)
# Out:
# InsertManyResult([ObjectId('65d9ccdc9482271ab2f6f991'), ObjectId('65d9ccdc9482271ab2f6f992'), ObjectId('65d9ccdc9482271ab2f6f993'), ObjectId('65d9ccdc9482271ab2f6f994'), ObjectId('65d9ccdc9482271ab2f6f995'), ObjectId('65d9ccdc9482271ab2f6f996'), ObjectId('65d9ccdc9482271ab2f6f997'), ObjectId('65d9ccdc9482271ab2f6f998'), ObjectId('65d9ccdc9482271ab2f6f999'), ObjectId('65d9ccdc9482271ab2f6f99a'), ObjectId('65d9ccdc9482271ab2f6f99b'), ObjectId('65d9ccdc9482271ab2f6f99c'), ObjectId('65d9ccdc9482271ab2f6f99d'), ObjectId('65d9ccdc9482271ab2f6f99e'), ObjectId('65d9ccdc9482271ab2f6f99f'), ObjectId('65d9ccdc9482271ab2f6f9a0'), ObjectId('65d9ccdc9482271ab2f6f9a1'), ObjectId('65d9ccdc9482271ab2f6f9a2'), ObjectId('65d9ccdc9482271ab2f6f9a3'), ObjectId('65d9ccdc9482271ab2f6f9a4'), ObjectId('65d9ccdc9482271ab2f6f9a5'), ObjectId('65d9ccdc9482271ab2f6f9a6'), ObjectId('65d9ccdc9482271ab2f6f9a7'), ObjectId('65d9ccdc9482271ab2f6f9a8'), ObjectId('65d9ccdc9482271ab2f6f9a9'), ObjectId('65d9ccdc9482271ab2f6
# ...

# %%
data.shape
# Out:
# (36188, 171)
